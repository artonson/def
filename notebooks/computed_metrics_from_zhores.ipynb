# %%
import os

# %%
zhores_dir = '/gpfs/gpfs0/3ddl/sharp_features/experiments'

# %%
with open('/logs/experiments_results/names_v2x.txt') as n, open('/logs/experiments_results/names_v2x_local.txt') as m: 
    for l1, l2 in zip(n, m):
        print('rsync --progress --append {host}:{base_dir}/{subdir}/{filename} {target_filename}'.format(
            host='a.artemov@cdise.login',
            base_dir=zhores_dir,
            subdir=l1.strip(),
            filename='agg_val.yaml',
            target_filename=l2.strip() + '_agg_val.yaml'
        ))
        
        print('rsync --progress --append {host}:{base_dir}/{subdir}/{filename} {target_filename}'.format(
            host='a.artemov@cdise.login',
            base_dir=zhores_dir,
            subdir=l1.strip(),
            filename='agg_test.yaml',
            target_filename=l2.strip() + '_agg_test.yaml'
        ))
# Out:
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-baseline/metrics/agg_val.yaml image-high-baseline_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-baseline/metrics/agg_test.yaml image-high-baseline_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-baseline-v2/metrics/agg_val.yaml image-high-baseline-v2_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-baseline-v2/metrics/agg_test.yaml image-high-baseline-v2_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-dgcnn4k-inputs-v2/gtn/metrics/agg_val.yaml image-high-dgcnn4k-inputs-v2_gtn_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-dgcnn4k-inputs-v2/gtn/metrics/agg_test.yaml image-high-dgcnn4k-inputs-v2_gtn_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-dgcnn4k-inputs-v2/gtn-v/metrics/agg_val.yaml image-high-dgcnn4k-inputs-v2_gtn-v_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-dgcnn4k-inputs-v2/gtn-v/metrics/agg_test.yaml image-high-dgcnn4k-inputs-v2_gtn-v_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-dgcnn4k-inputs-v2/v/metrics/agg_val.yaml image-high-dgcnn4k-inputs-v2_v_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-dgcnn4k-inputs-v2/v/metrics/agg_test.yaml image-high-dgcnn4k-inputs-v2_v_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-dgcnn4k-outputs/outn-nl001/metrics/agg_val.yaml image-high-dgcnn4k-outputs_outn-nl001_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-dgcnn4k-outputs/outn-nl001/metrics/agg_test.yaml image-high-dgcnn4k-outputs_outn-nl001_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-dgcnn4k-outputs-v2/outd-dl01/metrics/agg_val.yaml image-high-dgcnn4k-outputs-v2_outd-dl01_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-dgcnn4k-outputs-v2/outd-dl01/metrics/agg_test.yaml image-high-dgcnn4k-outputs-v2_outd-dl01_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-dgcnn4k-outputs-v2/outnd-nl001dl01/metrics/agg_val.yaml image-high-dgcnn4k-outputs-v2_outnd-nl001dl01_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-dgcnn4k-outputs-v2/outnd-nl001dl01/metrics/agg_test.yaml image-high-dgcnn4k-outputs-v2_outnd-nl001dl01_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-dgcnn4k-outputs-v2/outn-nl001/metrics/agg_val.yaml image-high-dgcnn4k-outputs-v2_outn-nl001_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-dgcnn4k-outputs-v2/outn-nl001/metrics/agg_test.yaml image-high-dgcnn4k-outputs-v2_outn-nl001_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet101-inputs-v2/gtn/metrics/agg_val.yaml image-high-resnet101-inputs-v2_gtn_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet101-inputs-v2/gtn/metrics/agg_test.yaml image-high-resnet101-inputs-v2_gtn_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet101-inputs-v2/gtn-v/metrics/agg_val.yaml image-high-resnet101-inputs-v2_gtn-v_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet101-inputs-v2/gtn-v/metrics/agg_test.yaml image-high-resnet101-inputs-v2_gtn-v_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet101-inputs-v2/v/metrics/agg_val.yaml image-high-resnet101-inputs-v2_v_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet101-inputs-v2/v/metrics/agg_test.yaml image-high-resnet101-inputs-v2_v_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet101-outputs-v2/outd-dl01/metrics/agg_val.yaml image-high-resnet101-outputs-v2_outd-dl01_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet101-outputs-v2/outd-dl01/metrics/agg_test.yaml image-high-resnet101-outputs-v2_outd-dl01_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet101-outputs-v2/outnd-nl001dl01/metrics/agg_val.yaml image-high-resnet101-outputs-v2_outnd-nl001dl01_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet101-outputs-v2/outnd-nl001dl01/metrics/agg_test.yaml image-high-resnet101-outputs-v2_outnd-nl001dl01_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet101-outputs-v2/outn-nl001/metrics/agg_val.yaml image-high-resnet101-outputs-v2_outn-nl001_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet101-outputs-v2/outn-nl001/metrics/agg_test.yaml image-high-resnet101-outputs-v2_outn-nl001_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet/resnet101/metrics/agg_val.yaml image-high-resnet_resnet101_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet/resnet101/metrics/agg_test.yaml image-high-resnet_resnet101_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet/resnet152/metrics/agg_val.yaml image-high-resnet_resnet152_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet/resnet152/metrics/agg_test.yaml image-high-resnet_resnet152_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet/resnet26/metrics/agg_val.yaml image-high-resnet_resnet26_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet/resnet26/metrics/agg_test.yaml image-high-resnet_resnet26_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet/resnet34/metrics/agg_val.yaml image-high-resnet_resnet34_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet/resnet34/metrics/agg_test.yaml image-high-resnet_resnet34_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet/resnet50/metrics/agg_val.yaml image-high-resnet_resnet50_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet/resnet50/metrics/agg_test.yaml image-high-resnet_resnet50_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet101-128k/metrics/agg_val.yaml image-high-resnet-v2_resnet101-128k_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet101-128k/metrics/agg_test.yaml image-high-resnet-v2_resnet101-128k_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet101-16k/metrics/agg_val.yaml image-high-resnet-v2_resnet101-16k_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet101-16k/metrics/agg_test.yaml image-high-resnet-v2_resnet101-16k_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet101-256k/metrics/agg_val.yaml image-high-resnet-v2_resnet101-256k_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet101-256k/metrics/agg_test.yaml image-high-resnet-v2_resnet101-256k_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet101-32k/metrics/agg_val.yaml image-high-resnet-v2_resnet101-32k_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet101-32k/metrics/agg_test.yaml image-high-resnet-v2_resnet101-32k_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet101/metrics/agg_val.yaml image-high-resnet-v2_resnet101_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet101/metrics/agg_test.yaml image-high-resnet-v2_resnet101_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet152/metrics/agg_val.yaml image-high-resnet-v2_resnet152_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet152/metrics/agg_test.yaml image-high-resnet-v2_resnet152_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet26/metrics/agg_val.yaml image-high-resnet-v2_resnet26_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet26/metrics/agg_test.yaml image-high-resnet-v2_resnet26_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet34/metrics/agg_val.yaml image-high-resnet-v2_resnet34_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet34/metrics/agg_test.yaml image-high-resnet-v2_resnet34_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet50/metrics/agg_val.yaml image-high-resnet-v2_resnet50_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-resnet-v2/resnet50/metrics/agg_test.yaml image-high-resnet-v2_resnet50_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-testonly-noscheduler-v2/d6w158-hist/metrics/agg_val.yaml image-high-testonly-noscheduler-v2_d6w158-hist_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-testonly-noscheduler-v2/d6w158-hist/metrics/agg_test.yaml image-high-testonly-noscheduler-v2_d6w158-hist_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-testonly-noscheduler-v2/dgcnn-4k-hist/metrics/agg_val.yaml image-high-testonly-noscheduler-v2_dgcnn-4k-hist_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/image-high-testonly-noscheduler-v2/dgcnn-4k-hist/metrics/agg_test.yaml image-high-testonly-noscheduler-v2_dgcnn-4k-hist_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/pc-high-baseline/metrics/agg_val.yaml pc-high-baseline_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/pc-high-baseline/metrics/agg_test.yaml pc-high-baseline_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/pc-high-baseline-v1/metrics/agg_val.yaml pc-high-baseline-v1_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/pc-high-baseline-v1/metrics/agg_test.yaml pc-high-baseline-v1_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/pc-high-d6w158-inputsize/128k/metrics/agg_val.yaml pc-high-d6w158-inputsize_128k_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/pc-high-d6w158-inputsize/128k/metrics/agg_test.yaml pc-high-d6w158-inputsize_128k_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/pc-high-d6w158-inputsize/16k/metrics/agg_val.yaml pc-high-d6w158-inputsize_16k_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/pc-high-d6w158-inputsize/16k/metrics/agg_test.yaml pc-high-d6w158-inputsize_16k_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/pc-high-d6w158-inputsize/32k/metrics/agg_val.yaml pc-high-d6w158-inputsize_32k_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/pc-high
metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/pc-high-outputs/dgcnn-4k-hist-outnd-nl001dl01/metrics/agg_test.yaml pc-high-outputs_dgcnn-4k-hist-outnd-nl001dl01_metrics_agg_test.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/pc-high-outputs/dgcnn-4k-hist-outn-nl001/metrics/agg_val.yaml pc-high-outputs_dgcnn-4k-hist-outn-nl001_metrics_agg_val.yaml
# rsync --progress --append a.artemov@cdise.login:/gpfs/gpfs0/3ddl/sharp_features/experiments/pc-high-outputs/dgcnn-4k-hist-outn-nl001/metrics/agg_test.yaml pc-high-outputs_dgcnn-4k-hist-outn-nl001_metrics_agg_test.yaml

# %%
import yaml

# %%
version = 'v2x'
split = 'test'

base_exp_results_dir = '/logs/experiments_results'
names_filename = os.path.join(base_exp_results_dir, 'names_{}_local.txt'.format(version))

metrics_by_file = {}
with open(names_filename) as m: 
    for l2 in m:
        target_filename = os.path.join(
            '/logs/experiments_results',
            version,
            '{}_agg_{}.yaml'.format(l2.strip(), split))
        with open(target_filename) as t:
            metrics_by_file[target_filename] = yaml.load(t, Loader=yaml.Loader)

# %%
from collections import OrderedDict

name_mapping = OrderedDict({
 'mean_bad_points_ratio_1r/' + split: 'Bad 1r /All',
 'mean_bad_points_ratio_1r_is_flat=False/' + split: 'Bad 1r /Sharp',
 'mean_bad_points_ratio_1r_dl1/' + split: 'Close Bad 1r /All',
 'mean_bad_points_ratio_1r_dl1_is_flat=False/' + split: 'Close Bad 1r /Sharp',
    
 'mean_bad_points_ratio_2r/' + split: 'Bad 2r /All',
 'mean_bad_points_ratio_2r_is_flat=False/' + split: 'Bad 2r /Sharp',
 'mean_bad_points_ratio_2r_dl1/' + split: 'Close Bad 2r /All',
 'mean_bad_points_ratio_2r_dl1_is_flat=False/' + split: 'Close Bad 2r /Sharp',
    
 'mean_bad_points_ratio_4r/' + split: 'Bad 4r /All',
 'mean_bad_points_ratio_4r_is_flat=False/' + split: 'Bad 4r /Sharp',
 'mean_bad_points_ratio_4r_dl1/' + split: 'Close Bad 4r /All',
 'mean_bad_points_ratio_4r_dl1_is_flat=False/' + split: 'Close Bad 4r /Sharp',

 'mean_bad_points_ratio_8r/' + split: 'Bad 8r /All',
 'mean_bad_points_ratio_8r_is_flat=False/' + split: 'Bad 8r /Sharp',
 'mean_bad_points_ratio_8r_dl1/' + split: 'Close Bad 8r /All',
 'mean_bad_points_ratio_8r_dl1_is_flat=False/' + split: 'Close Bad 8r /Sharp',
    
 'mean_bad_points_ratio_16r/' + split: 'Bad 16r /All',
 'mean_bad_points_ratio_16r_is_flat=False/' + split: 'Bad 16r /Sharp',
 'mean_bad_points_ratio_16r_dl1/' + split: 'Close Bad 16r /All',
 'mean_bad_points_ratio_16r_dl1_is_flat=False/' + split: 'Close Bad 16r /Sharp',

 'mean_balanced_accuracy/' + split: 'Accuracy /All',
 'mean_balanced_accuracy_is_flat=False/' + split: 'Accuracy /Sharp',
    
 'mean_iou/' + split: 'IoU /All',
 'mean_iou_is_flat=False/' + split: 'IoU /Sharp',
    
 'mean_rmse/' + split: 'RMSE /All',
 'mean_rmse_is_flat=False/' + split: 'RMSE /Sharp',
 'mean_rmse_dl1/' + split: 'Close RMSE /All',
 'mean_rmse_dl1_is_flat=False/' + split: 'Close RMSE /Sharp',
    
 'q90_rmse/' + split: 'Q 0.90 /All',
 'q90_rmse_is_flat=False/' + split: 'Q 0.90 /Sharp',
 'q90_rmse_dl1/' + split: 'Close Q 0.90 /All',
 'q90_rmse_dl1_is_flat=False/' + split: 'Close Q 0.90 /Sharp',
    
 'q95_rmse/' + split: 'Q 0.95 /All',
 'q95_rmse_is_flat=False/' + split: 'Q 0.95 /Sharp',
 'q95_rmse_dl1/' + split: 'Close Q 0.95 /All',
 'q95_rmse_dl1_is_flat=False/' + split: 'Close Q 0.95 /Sharp',

 'q99_rmse/' + split: 'Q 0.99 /All',
 'q99_rmse_is_flat=False/' + split: 'Q 0.99 /Sharp',
 'q99_rmse_dl1/' + split: 'Close Q 0.99 /All',
 'q99_rmse_dl1_is_flat=False/' + split: 'Close Q 0.99 /Sharp',

})

# %%
from collections import defaultdict
metric_values_by_name = defaultdict(list)

for filename, metrics in metrics_by_file.items():
#     print(filename)
#     if not 'outputs' in filename:
#         continue
    for name, mapped_name in name_mapping.items():
#         print(mapped_name, metrics[name])
        metric_values_by_name[filename].append(metrics[name])

# %%
header = 'Method\t' + '\t'.join(name_mapping.values())
print(header)
# Out:
# Method	Bad 1r /All	Bad 1r /Sharp	Close Bad 1r /All	Close Bad 1r /Sharp	Bad 2r /All	Bad 2r /Sharp	Close Bad 2r /All	Close Bad 2r /Sharp	Bad 4r /All	Bad 4r /Sharp	Close Bad 4r /All	Close Bad 4r /Sharp	Bad 8r /All	Bad 8r /Sharp	Close Bad 8r /All	Close Bad 8r /Sharp	Bad 16r /All	Bad 16r /Sharp	Close Bad 16r /All	Close Bad 16r /Sharp	Accuracy /All	Accuracy /Sharp	IoU /All	IoU /Sharp	RMSE /All	RMSE /Sharp	Close RMSE /All	Close RMSE /Sharp	Q 0.90 /All	Q 0.90 /Sharp	Close Q 0.90 /All	Close Q 0.90 /Sharp	Q 0.95 /All	Q 0.95 /Sharp	Close Q 0.95 /All	Close Q 0.95 /Sharp	Q 0.99 /All	Q 0.99 /Sharp	Close Q 0.99 /All	Close Q 0.99 /Sharp

# %%
files_order = [
    'pc-high-dw_d1w36_metrics_agg_{}.yaml'.format(split),
    'pc-high-dw_d2w48_metrics_agg_{}.yaml'.format(split),
    'pc-high-baseline_metrics_agg_{}.yaml'.format(split),
    'pc-high-dw_d4w88_metrics_agg_{}.yaml'.format(split),
    'pc-high-dw_d5w118_metrics_agg_{}.yaml'.format(split),
    'pc-high-dw_d6w158_metrics_agg_{}.yaml'.format(split),
    
    'image-high-baseline_metrics_agg_{}.yaml'.format(split),
    'image-high-resnet_resnet26_metrics_agg_{}.yaml'.format(split),
    'image-high-resnet_resnet34_metrics_agg_{}.yaml'.format(split),
    'image-high-resnet_resnet50_metrics_agg_{}.yaml'.format(split),
    'image-high-resnet_resnet101_metrics_agg_{}.yaml'.format(split),
    'image-high-resnet_resnet152_metrics_agg_{}.yaml'.format(split),
    
    'pc-high-baseline_metrics_agg_{}.yaml'.format(split),
    'pc-high-inputs_dgcnn4k-v_metrics_agg_{}.yaml'.format(split),
    'pc-high-inputs_dgcnn4k-gtn_metrics_agg_{}.yaml'.format(split),
    'pc-high-inputs_dgcnn4k-gtn-v_metrics_agg_{}.yaml'.format(split),
    
    'image-high-resnet_resnet101_metrics_agg_{}.yaml'.format(split),
    'image-high-resnet101-inputs_v_metrics_agg_{}.yaml'.format(split),
    'image-high-resnet101-inputs_gtn_metrics_agg_{}.yaml'.format(split),
    'image-high-resnet101-inputs_gtn-v_metrics_agg_{}.yaml'.format(split),
    
    'pc-high-baseline_metrics_agg_{}.yaml'.format(split),
    'pc-high-outputs_dgcnn-4k-hist-outd-dl01_metrics_agg_{}.yaml'.format(split),
    'pc-high-outputs_dgcnn-4k-hist-outn-nl001_metrics_agg_{}.yaml'.format(split),
    'pc-high-outputs_dgcnn-4k-hist-outnd-nl001dl01_metrics_agg_{}.yaml'.format(split),
    
    'image-high-resnet_resnet101_metrics_agg_{}.yaml'.format(split),
    'image-high-resnet101-outputs_outd-dl01_metrics_agg_{}.yaml'.format(split),
    'image-high-resnet101-outputs_outn-nl001_metrics_agg_{}.yaml'.format(split),
    'image-high-resnet101-outputs_outnd-nl001dl01_metrics_agg_{}.yaml'.format(split),
    
    'pc-high-d6w158-inputsize_16k_metrics_agg_{}.yaml'.format(split),
    'pc-high-d6w158-inputsize_32k_metrics_agg_{}.yaml'.format(split),
    'pc-high-dw_d6w158_metrics_agg_{}.yaml'.format(split),
    'pc-high-d6w158-inputsize_128k_metrics_agg_{}.yaml'.format(split),
    'pc-high-d6w158-inputsize_256k_metrics_agg_{}.yaml'.format(split),
    
    'image-high-resnet_resnet101-16k_metrics_agg_{}.yaml'.format(split),
    'image-high-resnet_resnet101-32k_metrics_agg_{}.yaml'.format(split),
    'image-high-resnet_resnet101-64k_metrics_agg_{}.yaml'.format(split),
    'image-high-resnet_resnet101-128k_metrics_agg_{}.yaml'.format(split),
    'image-high-resnet_resnet101-256k_metrics_agg_{}.yaml'.format(split),
    
    'pc-high-baseline_metrics_agg_{}.yaml'.format(split),
    'pc-high-noisy_high-0025_metrics_agg_{}.yaml'.format(split),
    'pc-high-noisy_high-005_metrics_agg_{}.yaml'.format(split),
    'pc-high-noisy_high-01_metrics_agg_{}.yaml'.format(split),
    'pc-high-noisy_high-02_metrics_agg_{}.yaml'.format(split),
    'pc-high-noisy_high-04_metrics_agg_{}.yaml'.format(split),
    'pc-high-noisy_high-08_metrics_agg_{}.yaml'.format(split),
    
    'image-high-baseline_metrics_agg_{}.yaml'.format(split),
    'image-high-dgcnn4k-inputs_v_metrics_agg_{}.yaml'.format(split),
    'image-high-dgcnn4k-inputs_gtn_metrics_agg_{}.yaml'.format(split),
    'image-high-dgcnn4k-inputs_gtn-v_metrics_agg_{}.yaml'.format(split),
    
    'image-high-baseline_metrics_agg_{}.yaml'.format(split),
    'image-high-dgcnn4k-outputs_outd-dl01_metrics_agg_{}.yaml'.format(split),
    'image-high-dgcnn4k-outputs_outn-nl001_metrics_agg_{}.yaml'.format(split),
    'image-high-dgcnn4k-outputs_outnd-nl001dl01_metrics_agg_{}.yaml'.format(split),
    
    'image-high-testonly_dgcnn-4k-hist_metrics_agg_{}.yaml'.format(split),
    'image-high-testonly_d6w158-hist_metrics_agg_{}.yaml'.format(split)
    
]

# %%
data_str = [
    name + '\t' + '\t'.join([
        str(value) 
        for value in metric_values_by_name[os.path.join('/logs/experiments_results', version, name)]])
    for name in files_order
]

print('\n'.join(data_str))
# Out:
# pc-high-dw_d1w36_metrics_agg_test.yaml	0.20245619118213654	0.4984791874885559	0.19643975794315338	0.49072104692459106	0.11257515102624893	0.2763066291809082	0.10832333564758301	0.27059975266456604	0.0462212860584259	0.11208891123533249	0.04334036260843277	0.10826745629310608	0.015552602708339691	0.03669942542910576	0.013828783296048641	0.034545332193374634	0.004952629562467337	0.011208295822143555	0.004175913520157337	0.010431742295622826	0.9630298614501953	0.907652735710144	0.3013964295387268	0.7529107332229614	0.021042516455054283	0.05054282024502754	0.020326921716332436	0.05077816918492317	0.05656066909432411	0.09480434954166414	0.056372521445155144	0.09476434662938121	0.0851425901055336	0.13806102946400606	0.08394896797835827	0.13699617013335097	0.20824764966964748	0.32481831908225944	0.19396728724241297	0.3269367435574525
