# %%
import pandas as pd

# %%
s = """00500041 # verts: 16180, # faces: 32356
before: max bb size: 61.336411, avg face area: 0.2669124881816364, avg edge length: 0.7979121214427187
after: max bb size: 40.0, avg face area: 0.11351471308492828, avg edge length: 0.5203513596142549

00500042 # verts: 9527, # faces: 19050
before: max bb size: 100.0, avg face area: 0.6038540265594912, avg edge length: 1.1959408723002645
after: max bb size: 40.0, avg face area: 0.0966166442495186, avg edge length: 0.4783763489201059

00500082 # verts: 25985, # faces: 51966
before: max bb size: 61.431409, avg face area: 0.20528846677456242, avg edge length: 0.6973513948158403
after: max bb size: 40.0, avg face area: 0.087036933370599, avg edge length: 0.4540683055573999

00500136 # verts: 14923, # faces: 29842
before: max bb size: 152.4, avg face area: 1.6476444376987203, avg edge length: 1.980206012727624
after: max bb size: 40.0, avg face area: 0.11350462160626615, avg edge length: 0.5197391109521323

00500149 # verts: 25912, # faces: 51852
before: max bb size: 125.0, avg face area: 1.1437856176835828, avg edge length: 1.6515028358315653
after: max bb size: 40.0, avg face area: 0.11712364725079889, avg edge length: 0.5284809074661011

00500166 # verts: 32002, # faces: 64016
before: max bb size: 25.4, avg face area: 0.05374434060588805, avg edge length: 0.35678347764604096
after: max bb size: 40.0, avg face area: 0.13328623127506492, avg edge length: 0.5618637443244741

00500348 # verts: 14164, # faces: 28324
before: max bb size: 155.045073, avg face area: 1.0560231409643857, avg edge length: 1.58616710075821
after: max bb size: 40.0, avg face area: 0.07028739991326616, avg edge length: 0.4092144484354456

00500403 # verts: 22517, # faces: 45030
before: max bb size: 100.0, avg face area: 0.5260636149911502, avg edge length: 1.118598192540599
after: max bb size: 40.0, avg face area: 0.08417017839858404, avg edge length: 0.4474392770162397

00500404 # verts: 15488, # faces: 30972
before: max bb size: 46.819806, avg face area: 0.15705937900847777, avg edge length: 0.6124489459943945
after: max bb size: 40.0, avg face area: 0.11463695425585972, avg edge length: 0.5232392000892907

00500405 # verts: 22274, # faces: 44544
before: max bb size: 90.0, avg face area: 0.4789475855600416, avg edge length: 1.0667987863511648
after: max bb size: 40.0, avg face area: 0.09460693048099587, avg edge length: 0.474132793933851

00500417 # verts: 113008, # faces: 227416
before: max bb size: 100.399139, avg face area: 0.17915295827847275, avg edge length: 0.6494525971425162
after: max bb size: 40.0, avg face area: 0.02843701386343846, avg edge length: 0.2587482735853008

00500442 # verts: 18964, # faces: 40216
before: max bb size: 270.0, avg face area: 3.3478203233713852, avg edge length: 2.8198839105567877
after: max bb size: 40.0, avg face area: 0.07347753796151188, avg edge length: 0.41776057934174626

00500505 # verts: 60007, # faces: 123026
before: max bb size: 602.101181, avg face area: 4.745060079516873, avg edge length: 3.3595915431124763
after: max bb size: 40.0, avg face area: 0.020942221087966062, avg edge length: 0.22319116116216203

00500683 # verts: 20900, # faces: 41796
before: max bb size: 220.0, avg face area: 2.637801247038274, avg edge length: 2.5025075421249663
after: max bb size: 40.0, avg face area: 0.08720004122440574, avg edge length: 0.4550013712954485

00500772 # verts: 25785, # faces: 51586
before: max bb size: 50.183524, avg face area: 0.11188619260303959, avg edge length: 0.5132612979843653
after: max bb size: 40.0, avg face area: 0.0710843780114982, avg edge length: 0.40910741779263265

00500912 # verts: 11147, # faces: 22294
before: max bb size: 25.7302, avg face area: 0.04406909265001437, avg edge length: 0.32236838429956777
after: max bb size: 40.0, avg face area: 0.10650445331633715, avg edge length: 0.5011517738681671

00501117 # verts: 69392, # faces: 138816
before: max bb size: 145.668326, avg face area: 0.4258107679298662, avg edge length: 1.004308010471999
after: max bb size: 40.0, avg face area: 0.032107490561418386, avg edge length: 0.2757793785512436

00501216 # verts: 22686, # faces: 45412
before: max bb size: 49.924153, avg face area: 0.1853150438644075, avg edge length: 0.6640238217099814
after: max bb size: 40.0, avg face area: 0.11896227158482499, avg edge length: 0.5320261090538532

00502539 # verts: 21382, # faces: 42764
before: max bb size: 70.0, avg face area: 0.3664734310822441, avg edge length: 0.9340172698897544
after: max bb size: 40.0, avg face area: 0.11966479382277358, avg edge length: 0.5337241542227167

00503288 # verts: 16816, # faces: 33628
before: max bb size: 101.6, avg face area: 1.1327774110163928, avg edge length: 1.642375026002903
after: max bb size: 40.0, avg face area: 0.17558084986924063, avg edge length: 0.6466043409460249

00503381 # verts: 33621, # faces: 67270
before: max bb size: 28.0, avg face area: 0.08230915380920349, avg edge length: 0.44296031706784394
after: max bb size: 40.0, avg face area: 0.16797786491674188, avg edge length: 0.6328004529540627

00503546 # verts: 9198, # faces: 18392
before: max bb size: 214.788203, avg face area: 3.2736398804245557, avg edge length: 2.795175095697216
after: max bb size: 40.0, avg face area: 0.11353507111591418, avg edge length: 0.520545366394674

00504478 # verts: 23823, # faces: 47354
before: max bb size: 48.356348999999994, avg face area: 0.19302054984308878, avg edge length: 0.678514199312508
after: max bb size: 40.0, avg face area: 0.1320737546770058, avg edge length: 0.5612617274414227

00506371 # verts: 23144, # faces: 46352
before: max bb size: 70.0, avg face area: 0.3212588792553719, avg edge length: 0.8655421925897662
after: max bb size: 40.0, avg face area: 0.10490085853236632, avg edge length: 0.4945955386227235

00506880 # verts: 14819, # faces: 29638
before: max bb size: 47.898758, avg face area: 0.15584437822606373, avg edge length: 0.609274934446856
after: max bb size: 40.0, avg face area: 0.10868325038613051, avg edge length: 0.5088022820523705

00507625 # verts: 11668, # faces: 23332
before: max bb size: 15.141905999999999, avg face area: 0.014827679349161418, avg edge length: 0.18683788505183646
after: max bb size: 40.0, avg face area: 0.10347419987598605, avg edge length: 0.4935650374578642

00508845 # verts: 23239, # faces: 46474
before: max bb size: 101.6, avg face area: 1.1622833871735823, avg edge length: 1.661567116410516
after: max bb size: 40.0, avg face area: 0.18015428532047592, avg edge length: 0.6541602820513843

00509172 # verts: 20429, # faces: 40854
before: max bb size: 60.056802, avg face area: 0.26754430160037446, avg edge length: 0.7982137463871488
after: max bb size: 40.0, avg face area: 0.11868375629564976, avg edge length: 0.5316391947657477"""

# %%
import re

# %%
re.match('(\d+) # verts: (\d+), # faces: (\d+)\nbefore: max bb size: (\d+\.\d+),', '00500041 # verts: 16180, # faces: 32356\nbefore: max bb size: 61.336411,').groups()
# Out:
# ('00500041', '16180', '32356', '61.336411')

# %%
df = []
for line in s.split('\n\n'):
#     print(line)
    m = re.match('(\d+) # verts: (\d+), # faces: (\d+)\nbefore: max bb size: (\d+\.\d+), avg face area: (\d+\.\d+), avg edge length: (\d+\.\d+)\nafter: max bb size: 40.0, avg face area: (\d\.\d+), avg edge length: (\d+\.\d+)', line)
    df.append(
        dict(zip(
            ('id', 'verts', 'faces', 'bb_size', 'face_area_orig', 'edge_len_orig', 'face_area_scale', 'edge_len_scale'),
            m.groups()
        ))
    )

# %%
df = pd.DataFrame(df)
df.verts = pd.to_numeric(df.verts)
df.faces = pd.to_numeric(df.faces)
df.bb_size = pd.to_numeric(df.bb_size)
df.face_area_orig = pd.to_numeric(df.face_area_orig)
df.edge_len_orig = pd.to_numeric(df.edge_len_orig)
df.face_area_scale = pd.to_numeric(df.face_area_scale)
df.edge_len_scale = pd.to_numeric(df.edge_len_scale)

df
# Out:
#           id   verts   faces     bb_size  face_area_orig  edge_len_orig  \
# 0   00500041   16180   32356   61.336411        0.266912       0.797912
# 1   00500042    9527   19050  100.000000        0.603854       1.195941
# 2   00500082   25985   51966   61.431409        0.205288       0.697351
# 3   00500136   14923   29842  152.400000        1.647644       1.980206
# 4   00500149   25912   51852  125.000000        1.143786       1.651503
# 5   00500166   32002   64016   25.400000        0.053744       0.356783
# 6   00500348   14164   28324  155.045073        1.056023       1.586167
# 7   00500403   22517   45030  100.000000        0.526064       1.118598
# 8   00500404   15488   30972   46.819806        0.157059       0.612449
# 9   00500405   22274   44544   90.000000        0.478948       1.066799
# 10  00500417  113008  227416  100.399139        0.179153       0.649453
# 11  00500442   18964   40216  270.000000        3.347820       2.819884
# ...

# %%
df.sort_values(by='faces')
# Out:
#           id   verts   faces     bb_size  face_area_orig  edge_len_orig  \
# 21  00503546    9198   18392  214.788203        3.273640       2.795175
# 1   00500042    9527   19050  100.000000        0.603854       1.195941
# 15  00500912   11147   22294   25.730200        0.044069       0.322368
# 25  00507625   11668   23332   15.141906        0.014828       0.186838
# 6   00500348   14164   28324  155.045073        1.056023       1.586167
# 24  00506880   14819   29638   47.898758        0.155844       0.609275
# 3   00500136   14923   29842  152.400000        1.647644       1.980206
# 8   00500404   15488   30972   46.819806        0.157059       0.612449
# 0   00500041   16180   32356   61.336411        0.266912       0.797912
# 19  00503288   16816   33628  101.600000        1.132777       1.642375
# 11  00500442   18964   40216  270.000000        3.347820       2.819884
# 27  00509172   20429   40854   60.056802        0.267544       0.798214
# ...
